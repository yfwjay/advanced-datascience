# %%
# Import the necessary libraries
import pandas as pd

# %%
# 1.Read the Csv titanic.csv
# Reading the csv file
my_dataframe = pd.read_csv(r"C:\Users\Admin\Desktop\MODCOM2\datascience\datsciencepdfs\Assessment\Assesment 1\titanic.csv")
my_dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2.Check if it is clean or not.
my_dataframe.info()

# 2columns have missing values: age and cabin
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 3.Clean the csv file. 
# •	Clean age column (fill mean of age). Clean cabin column (fill with unknown)
mean = my_dataframe['Age'].mean()
# mean
cleaned=my_dataframe['Age'].fillna(mean , inplace=True)




# •	Replace the values for the following column eg in survived, replace 1 with the word survived:
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12760\2029840102.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned=my_dataframe['Age'].fillna(mean , inplace=True)

# %%
# •	Replace the values for the following column eg in survived, replace 1 with the word survived:
my_dataframe['Survived'].replace({
    1 : 'Survived'
} , inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12760\4228940637.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   my_dataframe['Survived'].replace({

# %%
# 0-	Pclass

# 1-	First class

# 2-	Second Class 
# 3-    Third class 
my_dataframe['Pclass'].replace({
    1 : 'First Class' , 
    2 : 'Second Class' , 
    3 : 'Third Class' 
} , inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12760\3278110318.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   my_dataframe['Pclass'].replace({

# %%
# Embarked
# C-Cherbourg Q-Queenstorm
# S-Southermpton
# from pyparsing import C
# from re import Q
from re import S



my_dataframe['Embarked'].replace({

    S : 'Southermpton'
} , inplace= True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12760\878029519.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   my_dataframe['Embarked'].replace({

# %%
my_dataframe['Embarked'].replace({
    C : 'Cherbourg' ,  
} , inplace= True)

# %%
# my_dataframe['Embarked'].replace({
#     Q : 'Queenstorm' ,  
# } , inplace= True)

# %%
# We check if the rows have been filled
my_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
# 4.	How many people survived? How many are female? How many are male?
# my_dataframe
alive =  my_dataframe[my_dataframe['Survived'] == 'Survived']


survivor = alive.groupby(["Sex"]).count()
survivor
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          233       233     233   233  233    233    233     233   233
# male            109       109     109   109  109    109    109     109   109
#
#         Cabin  Embarked
# Sex
# female     91       231
# male       45       109

# %%
# 5.	How many are in firstclass? secondclass? thirdclass?

pclass = my_dataframe.groupby(['Pclass']).count()
pclass
# Out:
#               PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  \
# Pclass
# First Class           216       216   216  216  216    216    216     216
# Second Class          184       184   184  184  184    184    184     184
# Third Class           491       491   491  491  491    491    491     491
#
#               Fare  Cabin  Embarked
# Pclass
# First Class    216    176       214
# Second Class   184     16       184
# Third Class    491     12       491

# %%
# 6.	What is the average age?
average_age = my_dataframe['Age'].mean()
print("The average age is :", average_age)
# Out:
# The average age is : 29.69911764705882

# %%
# 7.	What is the mean fare?
average_fare= my_dataframe['Fare'].mean()
print("The average fare is : " , average_fare)
# Out:
# The average fare is :  32.204207968574636

# %%
# 8.	Did gender (Sex) have a statistically significant impact on the survival rate (0 means didn’t survive, 1 means survived) of passengers on the Titanic?
import scipy.stats as stats

#perform one sample t-test
# stats.ttest_1samp(a=my_dataframe['Sex'], popmean=342)
# t_statistic, p_value = stats.ttest_1samp(a=my_dataframe['Sex'], popmean=342)
# print(f"P-Value: {p_value}")


# popmean = 342 is the total number of passengers who survived

# %%
inferential= my_dataframe['Pclass'].replace({
    'First Class' : 1 , 
    'Second Class' : 2 , 
   'Third Class' : 3 
} , inplace=True)

# 9.	Did the passenger class (Pclass) have a statistically significant influence on the likelihood of surviving the Titanic disaster?

t_statistic, p_value = stats.ttest_1samp(a=my_dataframe['Pclass'], popmean=342)
print(f"P-Value: {p_value}")
# Out:
# P-Value: 0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sbn
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %%
# 10.	Plot a boxplot to check for outliers in Age and Sex
ax = sbn.boxplot(x = 'Age', y = 'Sex', data = my_dataframe ,palette = 'magma')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12760\3402960557.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sbn.boxplot(x = 'Age', y = 'Sex', data = my_dataframe ,palette = 'magma')

# %%
# 11.	Do a countplot of those who survived based on the gender.

sbn.countplot(my_dataframe['Survived'], palette = 'Oranges' ) 
plt.title("Those who survived based on the gender.")
plt.xlabel('Number survived')
plt.ylabel('Status')

# Counplot fails to accept the hue where we could have inserterd the gender
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12760\3964760789.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sbn.countplot(my_dataframe['Survived'], palette = 'Oranges' )
# Text(0, 0.5, 'Status')

# %%
# TASK2-Classification

# Obesity Dataset





# 1.	Read obesity classification.csv
# 2.	Perform the Machine Learning pipe cycle (get data, data cleaning, data enriching, and data visualization).
# 3.	Classify someone’s label based on their Height, Weight and BMI

# %%
obesity_dataframe = pd.read_csv(r"C:\Users\Admin\Desktop\MODCOM2\datascience\datsciencepdfs\Assessment\Assesment 1\Obesity Classification.csv")
obesity_dataframe
# Out:
#       ID  Age  Gender  Height  Weight   BMI          Label
# 0      1   25    Male     175      80  25.3  Normal Weight
# 1      2   30  Female     160      60  22.5  Normal Weight
# 2      3   35    Male     180      90  27.3     Overweight
# 3      4   40  Female     150      50  20.0    Underweight
# 4      5   45    Male     190     100  31.2          Obese
# ..   ...  ...     ...     ...     ...   ...            ...
# 103  106   11    Male     175      10   3.9    Underweight
# 104  107   16  Female     160      10   3.9    Underweight
# 105  108   21    Male     180      15   5.6    Underweight
# 106  109   26  Female     150      15   5.6    Underweight
# 107  110   31    Male     190      20   8.3    Underweight
#
# [108 rows x 7 columns]

# %%
# 2.	Perform the Machine Learning pipe cycle (get data, data cleaning, data enriching, and data visualization).

# %%
# data cleaning
obesity_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      108 non-null    int64
#  1   Age     108 non-null    int64
#  2   Gender  108 non-null    object
#  3   Height  108 non-null    int64
#  4   Weight  108 non-null    int64
#  5   BMI     108 non-null    float64
#  6   Label   108 non-null    object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 6.0+ KB

# %%
# data enriching
obesity_dataframe.describe()
# Out:
#                ID         Age      Height      Weight         BMI
# count  108.000000  108.000000  108.000000  108.000000  108.000000
# mean    56.046296   46.555556  166.574074   59.490741   20.549074
# std     31.917939   24.720620   27.873615   28.856233    7.583818
# min      1.000000   11.000000  120.000000   10.000000    3.900000
# 25%     28.750000   27.000000  140.000000   35.000000   16.700000
# 50%     56.500000   42.500000  175.000000   55.000000   21.200000
# 75%     83.250000   59.250000  190.000000   85.000000   26.100000
# max    110.000000  112.000000  210.000000  120.000000   37.200000

# %%
# data visualisation

import numpy as np

ax = sbn.barplot(x = 'Gender', y = 'Weight', data = obesity_dataframe ,palette = 'magma' , estimator= np.mean , hue= 'Label')

# %%
# TASK3-Regression

# Income.csv.

# Read income.csv

# 1.	Perform Data-Cleaning, Preprocessing, Visualizing.

# Predict the amount a income one will get is based on their age and experience.

# 2.	How much will I earn as a 30 year old with 10 years’ experience?

# %%
income_dataframe = pd.read_csv(r"C:\Users\Admin\Desktop\MODCOM2\datascience\datsciencepdfs\Assessment\Assesment 1\income.csv")
income_dataframe
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
income_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         20 non-null     int64
#  1   experience  20 non-null     int64
#  2   income      20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes

# %%
income_dataframe.describe()
# Out:
#              age  experience        income
# count  20.000000   20.000000     20.000000
# mean   39.650000    6.200000  40735.500000
# std    10.027725    4.124382   8439.797625
# min    23.000000    1.000000  27840.000000
# 25%    31.500000    3.750000  35452.500000
# 50%    40.000000    5.000000  40190.000000
# 75%    47.000000    9.000000  45390.000000
# max    58.000000   17.000000  63600.000000

# %%
# Data visualisation

ax = sbn.barplot(x = 'age', y = 'income', data = income_dataframe ,palette = 'magma' , estimator= np.mean , hue= 'experience')

# %%
# Predict the amount a income one will get is based on their age and experience.

# %%
array=income_dataframe.values
array
X=array[0:20,0:2] 
X
Y=array[0:20,2:4]
Y
# Out:
# array([[30450],
#        [35670],
#        [31580],
#        [40130],
#        [47830],
#        [41630],
#        [41340],
#        [37650],
#        [40250],
#        [45150],
#        [27840],
#        [46110],
#        [36720],
#        [34800],
#        [51300],
#        [38900],
#        [63600],
#        [30870],
#        [44190],
#        [48700]], dtype=int64)

# %%
from sklearn import model_selection
X_train,X_test,Y_train,Y_test=model_selection.train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
prediction=model.predict(X_test)
print("Predictions:",prediction)
# Out:
# Predictions: [[30822.32314416]
#  [31019.01707419]
#  [40089.99927433]
#  [34667.07934725]
#  [38315.14162031]
#  [41274.77513825]]

# %%
print("Expected outcome",Y_test)
# Out:
# Expected outcome [[30450]
#  [30870]
#  [38900]
#  [35670]
#  [40250]
#  [41630]]

# %%
from sklearn.metrics import r2_score 
print(" The model is: ",r2_score(prediction,Y_test)*100  ," accurate")
# Out:
#  The model is:  93.75352586949315  accurate

# %%
# 2.	How much will I earn as a 30 year old with 10 years’ experience?

earnings = [[30 , 10 ]]
expected = model.predict(earnings)
print("Your expected earnings is : " , expected)
# Out:
# Your expected earnings is :  [[49844.79794589]]

# %%
# TASK 4-Clustering using KMeans

# Customerdata.csv
 
# A Customer Credit Card Information Dataset which can be used for Identifying Loyal Customers, Customer Segmentation, Targeted Marketing and other such use cases in the Marketing Industry.
# 3.	Perform Data-Cleaning, Preprocessing, Visualizing.
# 4.	Read customerdata.csv
# 5.	Cluster customers with the same similarities
# 6.	View cluster 10.How Many are they? How often do they visit?

# %%
customer_dataframe = pd.read_csv(r"C:\Users\Admin\Desktop\MODCOM2\datascience\datsciencepdfs\Assessment\Assesment 1\customerdata.csv")
customer_dataframe
# Out:
#      Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0        1         87073            100000                   2
# 1        2         38414             50000                   3
# 2        3         17341             50000                   7
# 3        4         40496             30000                   5
# 4        5         47437            100000                   6
# ..     ...           ...               ...                 ...
# 655    656         51108             99000                  10
# 656    657         60732             84000                  10
# 657    658         53834            145000                   8
# 658    659         80655            172000                  10
# 659    660         80150            167000                   9
#
#      Total_visits_bank  Total_visits_online  Total_calls_made
# 0                    1                    1                 0
# 1                    0                   10                 9
# ...

# %%
customer_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sl_No                660 non-null    int64
#  1   Customer Key         660 non-null    int64
#  2   Avg_Credit_Limit     660 non-null    int64
#  3   Total_Credit_Cards   660 non-null    int64
#  4   Total_visits_bank    660 non-null    int64
#  5   Total_visits_online  660 non-null    int64
#  6   Total_calls_made     660 non-null    int64
# dtypes: int64(7)
# memory usage: 36.2 KB

# %%
customer_dataframe.describe()
# Out:
#             Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# count  660.000000    660.000000        660.000000          660.000000
# mean   330.500000  55141.443939      34574.242424            4.706061
# std    190.669872  25627.772200      37625.487804            2.167835
# min      1.000000  11265.000000       3000.000000            1.000000
# 25%    165.750000  33825.250000      10000.000000            3.000000
# 50%    330.500000  53874.500000      18000.000000            5.000000
# 75%    495.250000  77202.500000      48000.000000            6.000000
# max    660.000000  99843.000000     200000.000000           10.000000
#
#        Total_visits_bank  Total_visits_online  Total_calls_made
# count         660.000000           660.000000        660.000000
# mean            2.403030             2.606061          3.583333
# std             1.631813             2.935724          2.865317
# min             0.000000             0.000000          0.000000
# ...

# %%
array=customer_dataframe.values
array
X=array[0:660,0:9]
X
# Out:
# array([[     1,  87073, 100000, ...,      1,      1,      0],
#        [     2,  38414,  50000, ...,      0,     10,      9],
#        [     3,  17341,  50000, ...,      1,      3,      4],
#        ...,
#        [   658,  53834, 145000, ...,      1,      9,      1],
#        [   659,  80655, 172000, ...,      1,     15,      0],
#        [   660,  80150, 167000, ...,      0,     12,      2]], dtype=int64)

# %%
from sklearn.cluster import KMeans as km
model=km(n_clusters=20,random_state=42)
model.fit(X)
# Out:
# KMeans(n_clusters=20, random_state=42)

# %%
means = model.cluster_centers_
means
# Out:
# array([[2.14378378e+02, 1.87861351e+04, 1.18378378e+04, 3.93243243e+00,
#         2.24324324e+00, 2.40540541e+00, 4.59459459e+00],
#        [5.03107143e+02, 5.98726429e+04, 6.55000000e+04, 5.53571429e+00,
#         3.32142857e+00, 7.50000000e-01, 1.96428571e+00],
#        [1.98547170e+02, 8.05900943e+04, 1.14339623e+04, 3.58490566e+00,
#         2.20754717e+00, 2.20754717e+00, 4.50943396e+00],
#        [6.29750000e+02, 4.12595000e+04, 1.76875000e+05, 8.75000000e+00,
#         2.50000000e-01, 1.16250000e+01, 5.00000000e-01],
#        [2.27148649e+02, 5.10341757e+04, 1.23783784e+04, 4.14864865e+00,
#         2.21621622e+00, 2.22972973e+00, 4.24324324e+00],
#        [4.77341463e+02, 4.41098293e+04, 4.20243902e+04, 5.31707317e+00,
#         3.39024390e+00, 1.24390244e+00, 2.21951220e+00],
#        [5.02607143e+02, 3.13292500e+04, 6.64642857e+04, 5.50000000e+00,
#         3.21428571e+00, 1.10714286e+00, 2.21428571e+00],
# ...

# %%
clusters=pd.DataFrame(means ,columns=['Sl_No','Customer Key','Avg_Credit_Limit' , 'Total_Credit_Cards' , 'TT_Visits_bank' , 'TT_Visits_online' , 'TT_calls_made'] ) 
clusters
# Out:
#          Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0   214.378378  18786.135135      11837.837838            3.932432
# 1   503.107143  59872.642857      65500.000000            5.535714
# 2   198.547170  80590.094340      11433.962264            3.584906
# 3   629.750000  41259.500000     176875.000000            8.750000
# 4   227.148649  51034.175676      12378.378378            4.148649
# 5   477.341463  44109.829268      42024.390244            5.317073
# 6   502.607143  31329.250000      66464.285714            5.500000
# 7   511.473684  87683.526316      66815.789474            6.000000
# 8   516.478261  89363.913043      39173.913043            5.956522
# 9   639.857143  34722.428571     121428.571429            9.000000
# 10  193.168831  34703.636364      12402.597403            3.883117
# 11  193.753846  65826.569231      12538.461538            3.230769
# 12  631.750000  88593.250000     130500.000000            8.500000
# ...

# %%
customer_dataframe["group_number"]=model.labels_
customer_dataframe.head()
# Out:
#    Sl_No  Customer Key  Avg_Credit_Limit  Total_Credit_Cards  \
# 0      1         87073            100000                   2
# 1      2         38414             50000                   3
# 2      3         17341             50000                   7
# 3      4         40496             30000                   5
# 4      5         47437            100000                   6
#
#    Total_visits_bank  Total_visits_online  Total_calls_made  group_number
# 0                  1                    1                 0            14
# 1                  0                   10                 9             5
# 2                  1                    3                 4            16
# 3                  1                    1                 4             5
# 4                  0                   12                 3            14
